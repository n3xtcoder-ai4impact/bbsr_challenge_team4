# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
# Display all available columns in the dataframes
pd.set_option("display.max_columns", None)

# %% [markdown]
# ### load TBS dataset

# %%
tbaustoff_df = pd.read_csv('data/tBaustoff/tBaustoff_with_OBD_mapping.csv', low_memory=False)

print(tbaustoff_df.shape)
tbaustoff_df.head(1)
# Out:
# (815, 11)
#                   oekobaudatProcessUuid               oekobaudatDatastockUuid  \
# 0  3b1f0c75-07a4-4182-b310-5529fc5b54a6  22885a6e-1765-4ade-a35e-ae668bd07256
#
#   oekobaudatDatastockName  productId tBaustoffVersion         productName  \
# 0              OBD_2023_I          1          2024-Q4  Acetyliertes Holz
#
#    eolCategoryId    eolCategoryName eolScenarioUnbuiltReal  \
# 0              1  Holz - acetyliert                    EV+
#
#   eolScenarioUnbuiltPotential  technologyFactor
# 0                         EV+               0.0

# %% [markdown]
# ### load OBD datasets

# %%
# Load all three OBD files (adjust paths as needed)

obd_2020_df = pd.read_csv('data/OBD/OBD_2020_II.csv',
                            sep=';', encoding='ISO-8859-1', low_memory=False)
obd_2023_df = pd.read_csv('data/OBD/OBD_2023_I.csv',
                            sep=';', encoding='ISO-8859-1', low_memory=False)
obd_2024_df = pd.read_csv('data/OBD/OBD_2024_I.csv',
                            sep=';', encoding='ISO-8859-1', low_memory=False)

# Add column with DB version
obd_2020_df['OBD_Version'] = 'OBD_2020_II'
obd_2023_df['OBD_Version'] = 'OBD_2023_I'
obd_2024_df['OBD_Version'] = 'OBD_2024_I'

# Combine all OBD datasets into one DataFrame
OBD_all_years_df = pd.concat([obd_2020_df, obd_2023_df, obd_2024_df], ignore_index=True)
print(OBD_all_years_df.shape)
OBD_all_years_df.head(2)
# Out:
# (40411, 83)
#                                    UUID    Version  \
# 0  6b2b9708-14d8-4f3a-8a75-0b7481c5e0f8  00.03.000
# 1  6b2b9708-14d8-4f3a-8a75-0b7481c5e0f8  00.03.000
#
#                                       Name (de) Name (en)  \
# 0  Innenverzinnte Kupfer-Hausinstallationsrohre       NaN
# 1  Innenverzinnte Kupfer-Hausinstallationsrohre       NaN
#
#                    Kategorie (original)                        Kategorie (en)  \
# 0  'Metalle' / 'Kupfer' / 'Kupferrohre'  'Metals' / 'Copper' / 'Copper pipes'
# 1  'Metalle' / 'Kupfer' / 'Kupferrohre'  'Metals' / 'Copper' / 'Copper pipes'
#
#                     Konformität Laenderkennung              Typ  Referenzjahr  \
# 0  'DIN EN 15804' / 'ISO 14025'             DE  average dataset        2015.0
# 1  'DIN EN 15804' / 'ISO 14025'             DE  average dataset        2015.0
#
#    ...  SOP (A2) ODP (A2) POCP (A2) ADPF (A2) ADPE (A2) WDP (A2) Unnamed: 79  \
# 0  ...       NaN      NaN       NaN       NaN       NaN      NaN         NaN
# 1  ...       NaN      NaN       NaN       NaN       NaN      NaN         NaN
#
#    OBD_Version  Stueckgewicht (kg) Unnamed: 80
# 0  OBD_2020_II                 NaN         NaN
# 1  OBD_2020_II                 NaN         NaN
#
# [2 rows x 83 columns]

# %% [markdown]
# ### TBS with UUIDs details

# %%
# TBS unique UUID (assumed as mapped to OBDs) = 728
TBS_with_UUIDs_df = tbaustoff_df[tbaustoff_df['oekobaudatProcessUuid'].notna()]
print(TBS_with_UUIDs_df.shape)

TBS_unique_UUID=set(TBS_with_UUIDs_df['oekobaudatProcessUuid'].unique())
len(TBS_unique_UUID)
# Out:
# (728, 11)
# 728

# %% [markdown]
# ### Merge TBS with UUIDs details, with OBDs corresponding details

# %% [markdown]
# #### only keep unique rows by UUIDs

# %%
OBD_all_years_df_LessFeatures=OBD_all_years_df[['UUID', 'Name (de)', 'Name (en)', 'Kategorie (original)', 'Kategorie (en)', 'Typ', 'OBD_Version','Referenzjahr', 'Gueltig bis','UUID des Vorgängers',
                                        'Bezugsgroesse', 'Bezugseinheit', 'Referenzfluss-UUID','Referenzfluss-Name', 'Schuettdichte (kg/m3)','Flaechengewicht (kg/m2)',
                                        'Rohdichte (kg/m3)', 'Schichtdicke (m)']]
OBD_all_years_df_LessFeatures.shape
# Out:
# (40411, 18)

# %%
print(OBD_all_years_df_LessFeatures.duplicated().sum())

OBD_all_years_df_LessFeatures_2=OBD_all_years_df_LessFeatures.drop_duplicates()
OBD_all_years_df_LessFeatures_2.shape
# Out:
# 34626
# (5785, 18)

# %% [markdown]
# #### merge TBS with OBDs

# %%
# map OBD into TBS
combined_TBS_OBD = TBS_with_UUIDs_df.merge(OBD_all_years_df_LessFeatures_2, left_on=['oekobaudatProcessUuid','oekobaudatDatastockName'], right_on=['UUID','OBD_Version'], how='left')
print(combined_TBS_OBD.shape)
combined_TBS_OBD.head(2)
# Out:
# (728, 29)
#                   oekobaudatProcessUuid               oekobaudatDatastockUuid  \
# 0  3b1f0c75-07a4-4182-b310-5529fc5b54a6  22885a6e-1765-4ade-a35e-ae668bd07256
# 1  0dec19c7-53db-4cb9-bbba-4d44d3da62a9  ca70a7e6-0ea4-4e90-a947-d44585783626
#
#   oekobaudatDatastockName  productId tBaustoffVersion         productName  \
# 0              OBD_2023_I          1          2024-Q4  Acetyliertes Holz
# 1              OBD_2024_I          1          2024-Q4  Acetyliertes Holz
#
#    eolCategoryId    eolCategoryName eolScenarioUnbuiltReal  \
# 0              1  Holz - acetyliert                    EV+
# 1              1  Holz - acetyliert                    EV+
#
#   eolScenarioUnbuiltPotential  ...  Gueltig bis  \
# 0                         EV+  ...       2024.0
# 1                         EV+  ...       2026.0
#
#                     UUID des Vorgängers Bezugsgroesse Bezugseinheit  \
# 0  3b1f0c75-07a4-4182-b310-5529fc5b54a6             1            m3
# 1  3b1f0c75-07a4-4182-b310-5529fc5b54a6             1            m3
#
#                      Referenzfluss-UUID  \
# 0  ea4a7831-456f-4b70-9c5a-a21cd816acb9
# 1  ea4a7831-456f-4b70-9c5a-a21cd816acb9
#
#                       Referenzfluss-Name Schuettdichte (kg/m3)  \
# 0  Acetylated Wood (5% water content) m3                   NaN
# 1  Acetylated Wood (5% water content) m3                   NaN
#
#   Flaechengewicht (kg/m2)  Rohdichte (kg/m3)  Schichtdicke (m)
# 0                     NaN              510.0               NaN
# 1                     NaN                510               NaN
#
# [2 rows x 29 columns]

# %% [markdown]
# ##### overview of the combined TBS and OBDs dataset

# %%
def describe_columns_unique_nan(df):
    cat_cols = df.columns
    result = pd.DataFrame({
        'column': cat_cols,
        'count': [df[col].count() for col in cat_cols],
        'nunique': [df[col].nunique() for col in cat_cols],
        'null_count': [df[col].isnull().sum() for col in cat_cols],
        'null_percent': [round(df[col].isnull().sum() / len(df) * 100, 2) for col in cat_cols],
        'sample_values': [', '.join(df[col].dropna().sample(min(3, df[col].nunique())).astype(str).tolist()) for col in cat_cols]
    })
    
    return result

all_columns_unique_nan_summary = describe_columns_unique_nan(combined_TBS_OBD)
all_columns_unique_nan_summary.T
# Out:
#                                                               0   \
# column                                     oekobaudatProcessUuid
# count                                                        728
# nunique                                                      728
# null_count                                                     0
# null_percent                                                 0.0
# sample_values  ba58d8b9-945b-4428-b4e0-aecda8b3df18, aaf4baca...
#
#                                                               1   \
# column                                   oekobaudatDatastockUuid
# count                                                        728
# nunique                                                        3
# null_count                                                     0
# null_percent                                                 0.0
# sample_values  22885a6e-1765-4ade-a35e-ae668bd07256, 448d1096...
#
#                                                2             3   \
# column                    oekobaudatDatastockName     productId
# count                                         728           728
# nunique                                         3           260
# null_count                                      0             0
# null_percent                                  0.0           0.0
# sample_values  OBD_2023_I, OBD_2023_I, OBD_2024_I  294, 168, 12
#
#                              4   \
# column         tBaustoffVersion
# count                       728
# nunique                       1
# null_count                    0
# null_percent                0.0
# sample_values           2024-Q4
#
#                                                               5   \
# column                                               productName
# count                                                        728
# nunique                                                      260
# null_count                                                     0
# null_percent                                                 0.0
# sample_values  Kalkfarbe, Kalk-Gips-Innenputz auf Gipsbaustof...
#
#                           6   \
# column         eolCategoryId
# count                    728
# nunique                  107
# null_count                 0
# null_percent             0.0
# sample_values     11, 53, 13
#
#                                                               7   \
# column                                           eolCategoryName
# count                                                        728
# nunique                                                      107
# null_count                                                     0
# null_percent                                                 0.0
# sample_values  Holzwerkstoff - nicht beschichtet, Bims / Bläh...
#
#                                    8                            9   \
# column         eolScenarioUnbuiltReal  eolScenarioUnbuiltPotential
# count                             728                          728
# nunique                            10                           10
# null_count                          0                            0
# null_percent                      0.0                          0.0
# sample_values           EB, Dep+, EV-               Dep-, RC-, EV-
#
#                              10  \
# column         technologyFactor
# count                       728
# nunique                       5
# null_count                    0
# null_percent                0.0
# sample_values   0.0, 0.25, 0.75
#
#                                                               11  \
# column                                                      UUID
# count                                                        698
# nunique                                                      698
# null_count                                                    30
# null_percent                                                4.12
# sample_values  c7e171fb-d5eb-4867-9fb2-961dec81d6aa, 531ab34f...
#
#                                                               12  \
# column                                                 Name (de)
# count                                                        698
# nunique                                                      336
# null_count                                                    30
# null_percent                                                4.12
# sample_values  Stahl warmgewalzte Bleche (2-20mm), Hüttenstei...
#
#                                                               13  \
# column                                                 Name (en)
# count                                                        698
# nunique                                                      333
# null_count                                                    30
# null_percent                                                4.12
# sample_values  Aluminium sheet, Mineral fibre ceiling board (...
#
#                                                               14  \
# column                                      Kategorie (original)
# count                                                        698
# nunique                                                      129
# null_count                                                    30
# null_percent                                                4.12
# sample_values  'Metalle' / 'Aluminium' / 'Gussteile aus Alumi...
#
#                                                               15  \
# column                                            Kategorie (en)
# count                                                        698
# nunique                                                      131
# null_count                                                    30
# null_percent                                                4.12
# sample_values  'Plastics' / 'Sealing materials' / 'Bitumen', ...
#
#                             16                                   17  \
# column                     Typ                          OBD_Version
# count                      698                                  698
# nunique                      1                                    3
# null_count                  30                                   30
# null_percent              4.12                                 4.12
# sample_values  generic dataset  OBD_2023_I, OBD_2024_I, OBD_2020_II
#
#                                    18                      19  \
# column                   Referenzjahr             Gueltig bis
# count                             698                     698
# nunique                             3                       3
# null_count                         30                      30
# null_percent                     4.12                    4.12
# sample_values  2022.0, 2023.0, 2023.0  2026.0, 2026.0, 2024.0
#
#                                                               20  \
# column                                       UUID des Vorgängers
# count                                                        490
# nunique                                                      262
# null_count                                                   238
# null_percent                                               32.69
# sample_values  2632f4e8-7671-4d87-a8bc-9defdb54d117, d171cb17...
#
#                           21             22  \
# column         Bezugsgroesse  Bezugseinheit
# count                    698            698
# nunique                    9              5
# null_count                30             30
# null_percent            4.12           4.12
# sample_values        1, 1, 1      m3, kg, m
#
#                                                               23  \
# column                                        Referenzfluss-UUID
# count                                                        698
# nunique                                                      249
# null_count                                                    30
# null_percent                                                4.12
# sample_values  16da6ae2-d368-4bf8-9111-41b8297e33cd, 80e94985...
#
#                                                               24  \
# column                                        Referenzfluss-Name
# count                                                        698
# nunique                                                      249
# null_count                                                    30
# null_percent                                                4.12
# sample_values  PVC-Dachbahn (m2), Polyurethan (PU) Hartschaum...
#
#                                   25                       26  \
# column         Schuettdichte (kg/m3)  Flaechengewicht (kg/m2)
# count                              3                      196
# nunique                            2                      107
# null_count                       725                      532
# null_percent                   99.59                    73.08
# sample_values           500.0, 500.0          6.2, 104.0, 1.2
#
#                                 27                28
# column           Rohdichte (kg/m3)  Schichtdicke (m)
# count                          366                 0
# nunique                        150                 0
# null_count                     362               728
# null_percent                 49.73             100.0
# sample_values  2306.0, 26.25, 2360

# %% [markdown]
# from the above overview, we can see that 30 unique UUIDs in TBS is not found in any of the 3 OBD datasets

# %% [markdown]
# #### adjust combined dataframe of TBS with OBDs

# %% [markdown]
# ###### UUID in TBS not found in any of the 3 OBDs

# %%
# find the UUIDs that are not mapped to OBDs
emptyUUID=combined_TBS_OBD[combined_TBS_OBD['UUID'].isna()]
print(emptyUUID.shape)
emptyUUID.head(3)
# Out:
# (30, 29)
#                     oekobaudatProcessUuid  \
# 11   b8a9dd13-100b-40bf-b982-06937c4c5f65
# 148  b6e523cc-d329-49fb-b138-af531552862f
# 194  7b26b760-0cc0-48b1-8c61-9357cd2b7ba3
#
#                   oekobaudatDatastockUuid oekobaudatDatastockName  productId  \
# 11   22885a6e-1765-4ade-a35e-ae668bd07256              OBD_2023_I        101
# 148  22885a6e-1765-4ade-a35e-ae668bd07256              OBD_2023_I         24
# 194  22885a6e-1765-4ade-a35e-ae668bd07256              OBD_2023_I         67
#
#     tBaustoffVersion                                        productName  \
# 11           2024-Q4                                Glasfaser-Armierung
# 148          2024-Q4            Polyisobutylen (PIB) Kunststoffdachbahn
# 194          2024-Q4  Expandierte Perlit-Dämmplatten für den Innenbe...
#
#      eolCategoryId                                   eolCategoryName  \
# 11               3  Bitumenkaltkleber, Glasvlies, Glasfaserarmierung
# 148             16                                           KSTBahn
# 194             18                                     Mineralplatte
#
#     eolScenarioUnbuiltReal eolScenarioUnbuiltPotential  technologyFactor UUID  \
# 11                      EB                          EB              0.00  NaN
# 148                    EV-                         EV-              0.00  NaN
# 194                   Dep+                          SV              0.75  NaN
#
#     Name (de) Name (en) Kategorie (original) Kategorie (en)  Typ OBD_Version  \
# 11        NaN       NaN                  NaN            NaN  NaN         NaN
# 148       NaN       NaN                  NaN            NaN  NaN         NaN
# 194       NaN       NaN                  NaN            NaN  NaN         NaN
#
#      Referenzjahr  Gueltig bis UUID des Vorgängers Bezugsgroesse  \
# 11            NaN          NaN                 NaN           NaN
# 148           NaN          NaN                 NaN           NaN
# 194           NaN          NaN                 NaN           NaN
#
#     Bezugseinheit Referenzfluss-UUID Referenzfluss-Name Schuettdichte (kg/m3)  \
# 11            NaN                NaN                NaN                   NaN
# 148           NaN                NaN                NaN                   NaN
# 194           NaN                NaN                NaN                   NaN
#
#     Flaechengewicht (kg/m2) Rohdichte (kg/m3) Schichtdicke (m)
# 11                      NaN               NaN              NaN
# 148                     NaN               NaN              NaN
# 194                     NaN               NaN              NaN

# %%
# remove empty UUIDs from combined dataframe TBS OBD
combined_TBS_OBD_2=combined_TBS_OBD[combined_TBS_OBD['UUID'].notna()]
print(combined_TBS_OBD_2.duplicated().sum())
print(combined_TBS_OBD_2.shape)
combined_TBS_OBD_2.head(3)
# Out:
# 0
# (698, 29)
#                   oekobaudatProcessUuid               oekobaudatDatastockUuid  \
# 0  3b1f0c75-07a4-4182-b310-5529fc5b54a6  22885a6e-1765-4ade-a35e-ae668bd07256
# 1  0dec19c7-53db-4cb9-bbba-4d44d3da62a9  ca70a7e6-0ea4-4e90-a947-d44585783626
# 2  bd6d6d89-b76d-4002-a217-afffbb8aa308  448d1096-2017-4901-a560-f652a83c737e
#
#   oekobaudatDatastockName  productId tBaustoffVersion         productName  \
# 0              OBD_2023_I          1          2024-Q4  Acetyliertes Holz
# 1              OBD_2024_I          1          2024-Q4  Acetyliertes Holz
# 2             OBD_2020_II          2          2024-Q4    Aluminium Profil
#
#    eolCategoryId                                    eolCategoryName  \
# 0              1                                  Holz - acetyliert
# 1              1                                  Holz - acetyliert
# 2              2  Alu unbeschichtet od. eloxiert (Sz. Knetleg zu...
#
#   eolScenarioUnbuiltReal eolScenarioUnbuiltPotential  technologyFactor  \
# 0                    EV+                         EV+              0.00
# 1                    EV+                         EV+              0.00
# 2                    RC+                         CL+              0.75
#
#                                    UUID                            Name (de)  \
# 0  3b1f0c75-07a4-4182-b310-5529fc5b54a6  Acetyliertes Holz (1 m³, 510 kg/m³)
# 1  0dec19c7-53db-4cb9-bbba-4d44d3da62a9  Acetyliertes Holz (1 m3, 510 kg/m3)
# 2  bd6d6d89-b76d-4002-a217-afffbb8aa308                     Aluminium Profil
#
#                            Name (en)  \
# 0  Acetylated wood (1 m³, 510 kg/m³)
# 1  Acetylated wood (1 m3, 510 kg/m3)
# 2                  Aluminium section
#
#                                 Kategorie (original)  \
# 0  'Holz' / 'Modifiziertes Holz' / 'Acetyliertes ...
# 1  'Holz' / 'Modifiziertes Holz' / 'Acetyliertes ...
# 2        'Metalle' / 'Aluminium' / 'Aluminiumprofil'
#
#                                       Kategorie (en)              Typ  \
# 0  'Wood' / 'End-of-life processes' / 'EoL partic...  generic dataset
# 1       'Wood' / 'Modified wood' / 'Acetylated wood'  generic dataset
# 2      'Metals' / 'Aluminium' / 'Aluminium profiles'  generic dataset
#
#    OBD_Version  Referenzjahr  Gueltig bis  \
# 0   OBD_2023_I        2022.0       2024.0
# 1   OBD_2024_I        2023.0       2026.0
# 2  OBD_2020_II        2018.0       2022.0
#
#                     UUID des Vorgängers Bezugsgroesse Bezugseinheit  \
# 0  3b1f0c75-07a4-4182-b310-5529fc5b54a6             1            m3
# 1  3b1f0c75-07a4-4182-b310-5529fc5b54a6             1            m3
# 2                                   NaN             1            kg
#
#                      Referenzfluss-UUID  \
# 0  ea4a7831-456f-4b70-9c5a-a21cd816acb9
# 1  ea4a7831-456f-4b70-9c5a-a21cd816acb9
# 2  fa4d0c5b-122a-44db-b6c3-ce03a0c6f794
#
#                       Referenzfluss-Name Schuettdichte (kg/m3)  \
# 0  Acetylated Wood (5% water content) m3                   NaN
# 1  Acetylated Wood (5% water content) m3                   NaN
# 2             Aluminium-Extrusionsprofil                   NaN
#
#   Flaechengewicht (kg/m2) Rohdichte (kg/m3) Schichtdicke (m)
# 0                     NaN             510.0              NaN
# 1                     NaN               510              NaN
# 2                     NaN            2700.0              NaN

# %% [markdown]
# #### overview of the current UUIDs in TBS mapped with the 3 OBDs

# %%
all_columns_unique_nan_summary = describe_columns_unique_nan(combined_TBS_OBD_2)
all_columns_unique_nan_summary.T
# Out:
#                                                               0   \
# column                                     oekobaudatProcessUuid
# count                                                        698
# nunique                                                      698
# null_count                                                     0
# null_percent                                                 0.0
# sample_values  f9f742db-d695-456a-9793-0636eab7df05, d5df3d3b...
#
#                                                               1   \
# column                                   oekobaudatDatastockUuid
# count                                                        698
# nunique                                                        3
# null_count                                                     0
# null_percent                                                 0.0
# sample_values  22885a6e-1765-4ade-a35e-ae668bd07256, 22885a6e...
#
#                                                   2             3   \
# column                       oekobaudatDatastockName     productId
# count                                            698           698
# nunique                                            3           260
# null_count                                         0             0
# null_percent                                     0.0           0.0
# sample_values  OBD_2020_II, OBD_2020_II, OBD_2020_II  85, 314, 108
#
#                              4   \
# column         tBaustoffVersion
# count                       698
# nunique                       1
# null_count                    0
# null_percent                0.0
# sample_values           2024-Q4
#
#                                                               5   \
# column                                               productName
# count                                                        698
# nunique                                                      260
# null_count                                                     0
# null_percent                                                 0.0
# sample_values  Edelstahlblech, Lehmbauplatte mit CL-Nachweis,...
#
#                           6   \
# column         eolCategoryId
# count                    698
# nunique                  107
# null_count                 0
# null_percent             0.0
# sample_values    10, 110, 16
#
#                                                               7   \
# column                                           eolCategoryName
# count                                                        698
# nunique                                                      107
# null_count                                                     0
# null_percent                                                 0.0
# sample_values  DS Pflanzenfaser mit Zusatzstoffen (FSM, Binde...
#
#                                    8                            9   \
# column         eolScenarioUnbuiltReal  eolScenarioUnbuiltPotential
# count                             698                          698
# nunique                            10                           10
# null_count                          0                            0
# null_percent                      0.0                          0.0
# sample_values          Dep+, RC+, EV-                CL+, RC+, RC-
#
#                              10  \
# column         technologyFactor
# count                       698
# nunique                       5
# null_count                    0
# null_percent                0.0
# sample_values     0.5, 1.0, 1.0
#
#                                                               11  \
# column                                                      UUID
# count                                                        698
# nunique                                                      698
# null_count                                                     0
# null_percent                                                 0.0
# sample_values  422b2446-8a3f-457d-b47b-4728b2869d86, 286b0072...
#
#                                                               12  \
# column                                                 Name (de)
# count                                                        698
# nunique                                                      336
# null_count                                                     0
# null_percent                                                 0.0
# sample_values  PE-Noppenfolie zur Abdichtung, Unterspannbahn ...
#
#                                                               13  \
# column                                                 Name (en)
# count                                                        698
# nunique                                                      333
# null_count                                                     0
# null_percent                                                 0.0
# sample_values  Polystyrene foam filling (without binder), Ure...
#
#                                                               14  \
# column                                      Kategorie (original)
# count                                                        698
# nunique                                                      129
# null_count                                                     0
# null_percent                                                 0.0
# sample_values  'Mineralische Baustoffe' / 'Zuschläge' / 'Sand...
#
#                                                               15  \
# column                                            Kategorie (en)
# count                                                        698
# nunique                                                      131
# null_count                                                     0
# null_percent                                                 0.0
# sample_values  'Mineral building products' / 'Asphalt' / 'Bas...
#
#                             16                                  17  \
# column                     Typ                         OBD_Version
# count                      698                                 698
# nunique                      1                                   3
# null_count                   0                                   0
# null_percent               0.0                                 0.0
# sample_values  generic dataset  OBD_2023_I, OBD_2023_I, OBD_2024_I
#
#                                    18                      19  \
# column                   Referenzjahr             Gueltig bis
# count                             698                     698
# nunique                             3                       3
# null_count                          0                       0
# null_percent                      0.0                     0.0
# sample_values  2023.0, 2023.0, 2018.0  2024.0, 2024.0, 2026.0
#
#                                                               20  \
# column                                       UUID des Vorgängers
# count                                                        490
# nunique                                                      262
# null_count                                                   208
# null_percent                                                29.8
# sample_values  f34786e7-0953-4085-9f3d-955481cdd4ea, 6d3a545c...
#
#                           21             22  \
# column         Bezugsgroesse  Bezugseinheit
# count                    698            698
# nunique                    9              5
# null_count                 0              0
# null_percent             0.0            0.0
# sample_values        1, 1, 1     m3, kg, qm
#
#                                                               23  \
# column                                        Referenzfluss-UUID
# count                                                        698
# nunique                                                      249
# null_count                                                     0
# null_percent                                                 0.0
# sample_values  09d32545-f3a5-4e53-b0a9-ac9fec1f24fb, eda3a44d...
#
#                                                               24  \
# column                                        Referenzfluss-Name
# count                                                        698
# nunique                                                      249
# null_count                                                     0
# null_percent                                                 0.0
# sample_values  Extrudiertes Polystyrol (XPS) m3, Polyurethan ...
#
#                                   25                       26  \
# column         Schuettdichte (kg/m3)  Flaechengewicht (kg/m2)
# count                              3                      196
# nunique                            2                      107
# null_count                       695                      502
# null_percent                   99.57                    71.92
# sample_values             500, 500.0         24.07, 6.2, 30.0
#
#                                 27                28
# column           Rohdichte (kg/m3)  Schichtdicke (m)
# count                          366                 0
# nunique                        150                 0
# null_count                     332               698
# null_percent                 47.56             100.0
# sample_values  701.0, 1500, 1350.0

# %% [markdown]
# from the above overview, we could drop the columns 'Schichtdicke (m)' (= only null) and 'Schuettdichte (kg/m3)' (= almost always null)

# %%
combined_TBS_OBD_3= combined_TBS_OBD_2.drop(columns=['Schichtdicke (m)','Schuettdichte (kg/m3)']) 
print(combined_TBS_OBD_2.shape) 
print(combined_TBS_OBD_3.shape)
# Out:
# (698, 29)
# (698, 27)

# %% [markdown]
# ### Reference to test the mapping method of TBS empty UUIDs = combined_TBS_OBD_3 dataframe

# %%
# find TBS columns
TBS_columns=list(tbaustoff_df.columns)
tbaustoff_df.shape
# Out:
# (815, 11)

# %% [markdown]
# #### reference test = mapped dataframe between TBS with OBDs

# %%
# keep TBS columns only
ref_mapped_TBS_df = combined_TBS_OBD_3[TBS_columns]
print(ref_mapped_TBS_df.shape)
ref_mapped_TBS_df.head(1)
# Out:
# (698, 11)
#                   oekobaudatProcessUuid               oekobaudatDatastockUuid  \
# 0  3b1f0c75-07a4-4182-b310-5529fc5b54a6  22885a6e-1765-4ade-a35e-ae668bd07256
# 1  0dec19c7-53db-4cb9-bbba-4d44d3da62a9  ca70a7e6-0ea4-4e90-a947-d44585783626
#
#   oekobaudatDatastockName  productId tBaustoffVersion         productName  \
# 0              OBD_2023_I          1          2024-Q4  Acetyliertes Holz
# 1              OBD_2024_I          1          2024-Q4  Acetyliertes Holz
#
#    eolCategoryId    eolCategoryName eolScenarioUnbuiltReal  \
# 0              1  Holz - acetyliert                    EV+
# 1              1  Holz - acetyliert                    EV+
#
#   eolScenarioUnbuiltPotential  technologyFactor
# 0                         EV+               0.0
# 1                         EV+               0.0

# %%
# Save reference table of mapped TBS
ref_mapped_TBS_df.to_csv("Reference_results_mapped_TBS_products_with_OBD_genericUUIDs.csv", index=False)

# %% [markdown]
# #### reference test = UNMAPPED dataframe between TBS with OBDs

# %%
ref_unmapped_TBS_df= ref_mapped_TBS_df.copy()
print(ref_unmapped_TBS_df.duplicated().sum())
print(ref_unmapped_TBS_df.shape)
ref_unmapped_TBS_df.head(1)
# Out:
# 0
# (698, 11)
#                   oekobaudatProcessUuid               oekobaudatDatastockUuid  \
# 0  3b1f0c75-07a4-4182-b310-5529fc5b54a6  22885a6e-1765-4ade-a35e-ae668bd07256
# 1  0dec19c7-53db-4cb9-bbba-4d44d3da62a9  ca70a7e6-0ea4-4e90-a947-d44585783626
#
#   oekobaudatDatastockName  productId tBaustoffVersion         productName  \
# 0              OBD_2023_I          1          2024-Q4  Acetyliertes Holz
# 1              OBD_2024_I          1          2024-Q4  Acetyliertes Holz
#
#    eolCategoryId    eolCategoryName eolScenarioUnbuiltReal  \
# 0              1  Holz - acetyliert                    EV+
# 1              1  Holz - acetyliert                    EV+
#
#   eolScenarioUnbuiltPotential  technologyFactor
# 0                         EV+               0.0
# 1                         EV+               0.0

# %%
columns_to_empty = ['oekobaudatProcessUuid','oekobaudatDatastockUuid','oekobaudatDatastockName']

for col in columns_to_empty:
    ref_unmapped_TBS_df[col] = ''

# %%
print(ref_unmapped_TBS_df.shape)
print(ref_unmapped_TBS_df.duplicated().sum())
ref_unmapped_TBS_df.head(1)
# Out:
# (698, 11)
# 438
#   oekobaudatProcessUuid oekobaudatDatastockUuid oekobaudatDatastockName  \
# 0
# 1
#
#    productId tBaustoffVersion         productName  eolCategoryId  \
# 0          1          2024-Q4  Acetyliertes Holz               1
# 1          1          2024-Q4  Acetyliertes Holz               1
#
#      eolCategoryName eolScenarioUnbuiltReal eolScenarioUnbuiltPotential  \
# 0  Holz - acetyliert                    EV+                         EV+
# 1  Holz - acetyliert                    EV+                         EV+
#
#    technologyFactor
# 0               0.0
# 1               0.0

# %%
ref_unmapped_TBS_df_2=ref_unmapped_TBS_df.drop_duplicates()
print(ref_unmapped_TBS_df_2.shape)
print(ref_unmapped_TBS_df_2.duplicated().sum())
ref_unmapped_TBS_df_2.head(1)
# Out:
# (260, 11)
# 0
#   oekobaudatProcessUuid oekobaudatDatastockUuid oekobaudatDatastockName  \
# 0
# 2
#
#    productId tBaustoffVersion         productName  eolCategoryId  \
# 0          1          2024-Q4  Acetyliertes Holz               1
# 2          2          2024-Q4    Aluminium Profil              2
#
#                                      eolCategoryName eolScenarioUnbuiltReal  \
# 0                                  Holz - acetyliert                    EV+
# 2  Alu unbeschichtet od. eloxiert (Sz. Knetleg zu...                    RC+
#
#   eolScenarioUnbuiltPotential  technologyFactor
# 0                         EV+              0.00
# 2                         CL+              0.75

# %%
# Save reference table of unmapped TBS
ref_unmapped_TBS_df_2.to_csv("Reference_results_UNmapped_TBS_products_with_OBD_genericUUIDs.csv", index=False)
